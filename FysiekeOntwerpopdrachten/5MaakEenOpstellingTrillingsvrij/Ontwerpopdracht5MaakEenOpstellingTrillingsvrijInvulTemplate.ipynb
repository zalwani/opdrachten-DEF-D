# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 5 Invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.

# %% [markdown]
# | Groep: 6     |  |
# | :-------------|:-------------|
# | Bob Villerius| 6483895 |
# | Wout Zeilmaker| 6585043 |
# | Zulfiqar Alwani | 6281265 |

# %% [markdown]
# ## Opdracht 1: Planning.

# %% [markdown]
# | Planning Groep: 6    |Tijdstip / Tijdspanne  | door wie  |
# |---|---|---|
# | Arduino testen| 1100-1215 | Bob |
# | ontwerp-eis berekenen| 1100-1215 | Wout, Zul|
# | fabricage ontwerp | 1330-1515 | hele groep |
# | meten en itereren | 1515-1630 | hele groep |
# | opstelling en ontwerp gebouwd | 1515 |hele groep|
# | Getest, geitereerd en metingen klaar| 1630 | hele groep|
# | Pauze 1| 1230-1330 | hele groep |
# | Pauze 2| 1530-1540 | hele groep |

# %% [markdown]
# Run onderstaande cel om alle benodigde libraries te laden. Mogelijk voeg je er zelf nog een aantal toe later vandaag.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import time
import math

# %% [markdown]
# ## Opdracht 2a: Opsplitsen taak 1: Arduino
# Vul onderstaande tabel in:

# %% [markdown]
# | onderwerp    | antwoord  |
# |---|---|
# | hoe moeilijk (schaal 1 - 10) | 5 (relatief makkelijk) |
# | hoe lang voor één meting | 10 seconden|
# | verwacht nauwkeurigheid meting | onzekerheid in amplitude is 1 cm, de onzekerheid in de frequentie is 0.5 Hz |

# %% [markdown]
# ## Opdracht 2b: Opsplitsen taak 2: afleiding ontwerpeis

# %%
# Bereken hier je benodigde kantelfrequentie
# er moet gedempt worden met een factor 3 bij een f van 5 Hz, A_m/A_v=-1/3 = 1/(1-(2pi*f)^2/(2pi*f_0)^2
#na omschrijven en invullen, blijkt de cutoff frequency f_0= 2.5 Hz precies, dit op papier berekent.

# %%
# Voeg hier je plot in
f_0= 2.5 #hz
g= 9.812 #m/s^2


f= np.linspace(0,15,200)
x= 2*np.pi*f
y0= np.abs(1/(1-((2*np.pi*f)**2)/((2*np.pi*f_0)**2)))
plt.loglog(x,y0)

plt.grid()
plt.title('bodeplot')
plt.xlabel('log(omega)')
plt.ylabel('log(|Am/Av|)')
# Out:
# Text(0, 0.5, 'log(|Am/Av|)')

# %%
# Bereken hier de minimale Delta-x waarbij je aan de eis van de opdracht voldoet.
w_0= 2*np.pi*f_0 #hz
g= 9.812 # m/s^2
delta_x= g/(w_0)**2 #m
print('de waarde van delta x in centimeter is',delta_x*100)
# Out:
# de waarde van delta x in centimeter is 3.9766538155944726

# %% [markdown]
# ## Opdracht 3: Plot de grafiek.

# %%
# Voeg hier je plot in. Lees goed de opdracht wat er in de grafiek moet staan!
# Het is ook handig om je grafiek op te slaan, doe dat door met plt.savefig().

f_0= 2.5 #hz
m= np.linspace(0,3,100)
c_1= (m*g)/delta_x
c_2= (m*g)/(2*delta_x)
c_5= (m*g)/(5*delta_x)


plt.plot(m,c_1, label= 'd')
plt.plot(m,c_2, label= '2d')
plt.plot(m,c_5, label= '5d')
plt.grid()
plt.legend()
plt.title('plot')
plt.xlabel('massa [kg]')
plt.ylabel('veercontstante C [N/m]')
plt.savefig('opdracht5deltaxplot')

# %%
#dit is erbij gekomen na opdracht 6, we hebben gekozen voor een vaste massa van precies 500 g uiteindelijk
#bepalen van veerconstante hierbij

g= 9.812
meind= 0.500 #kg
c_conclusie= (meind*g)/(2*delta_x)

print(c_conclusie)

#dus een veerconstante van ongeveer 61.7 N/m
# Out:
# 61.68502750680849

# %% [markdown]
# ## Opdracht 4: Verander $\Delta x$.

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - De massa m te verhogen op de opstelling
# - De veerconstante C verlagen in de opstelling
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
# Als groep gaan we mikken op een $\Delta x$ van 2d is ongeveer 8 cm, dit omdat er altijd extra demping nodig is rekening houdend met bijv wrijving.
# We kiezen om de massa te varieren, omdat dit gemakkelijker is bij iedere stap te wegen t.o.v de veerconstante C

# %% [markdown]
# ## Opdracht 5: Schets.

# %% [markdown]
# ##### schets opstelling:
#
# ![alt text](opdracht5schetsmassaveer.png)

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# **Gekozen voor 2*$\Delta x$, dus 8 cm**
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# **De gekozen  $\Delta x$ wordt behaald met zowel massa als uitrekking van de veer en onze zelfgemaakte elastieken**
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# **De veer kan maximaal een uitrekking doen van ongeveer $\Delta x$ is 80 cm, en het systeem heeft een limiet qua gewicht erop van ongeveer 5 kg aan massa**
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# **Dit zou genoeg moeten zijn, we verwachtten maximaal 3 kg aan gewicht te gebruiken zoals aangegeven in voorgaande plot, en de uitrekking moet max een 2 keer $\Delta x$ hebben van 8 cm**
#
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# **Voldoen aan de eis zou moeten lukken met gebouwde opstelling en materialen, dus een demping van 5 Hz dempen met een factor 3 met een uitrekking van maximaal 8 cm**
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %%
# Voeg hier je plot in
f_0= 2.5 #hz
g= 9.812 #m/s^2
#bereken nieuwe eigenfrequentie van systeem f_1, 
# uit de differentiaal vergelijking volgt w_1= sqrt(g/delta_x), waarbij onze nieuwe deltax= 2*deltax= 8 cm = 0.08 m

w_1= np.sqrt(g/0.08)
f_1= w_1/(2*np.pi) #eigenfrequentie nieuw syteem in hz
f= np.linspace(0,15,200)
x= 2*np.pi*f
y0= np.abs(1/(1-((2*np.pi*f)**2)/((2*np.pi*f_0)**2)))
y1= np.abs(1/(1-((2*np.pi*f)**2)/((2*np.pi*f_1)**2)))
plt.loglog(x,y0)
plt.loglog(x,y1)
plt.grid()
plt.show
plt.grid()
plt.show
plt.title('amplitudeoverdracht vs frequentie')
plt.xlabel('log(omega)')
plt.ylabel('log(|Am/Av|)')
# Out:
# Text(0, 0.5, 'log(|Am/Av|)')

# %% [markdown]
# ## Opdracht 7: Plotten maar

# %%
# Voeg hier je plot in
f_0= 2.5 #hz
g= 9.812 #m/s^2
#bereken nieuwe eigenfrequentie van systeem f_1, 
# uit de differentiaal vergelijking volgt w_1= sqrt(g/delta_x), waarbij onze nieuwe deltax= 2*deltax= 8 cm = 0.08 m
f_data= np.array([4.9, 5.6, 5.9, 6.2, 6.9, 6.2], dtype=float)
A_v= np.array([3.31, 4.23, 4.47, 5.89, 6.49, 6.77], dtype=float) #in cm
A_m= np.array([0.21, 0.26,0.30, 0.34, 0.48, 0.51], dtype=float) #beide in cm, verhoudingen delen weg

#onzekerheden
u_A_m=1 #cm
u_A_v=1#cm
u_verhouding = np.sqrt((u_A_m/A_m)**2+(u_A_v/A_v)**2)

u_F=0.5

w_1= np.sqrt(g/0.08)
f_1= w_1/(2*np.pi) #eigenfrequentie nieuw syteem in hz
f= np.linspace(0,15,200)
x= 2*np.pi*f
y0= np.abs(1/(1-((2*np.pi*f)**2)/((2*np.pi*f_0)**2)))
y1= np.abs(1/(1-((2*np.pi*f)**2)/((2*np.pi*f_1)**2)))

plt.errorbar(f_data, np.abs(A_m/A_v), xerr=u_F, yerr=u_verhouding, linestyle= 'None')
plt.scatter(f_data, np.abs(A_m/A_v))

plt.plot(x,y0)
plt.plot(x,y1)
plt.xscale('log')
plt.yscale('log')
plt.grid()
plt.show
plt.title('amplitudeoverdracht vs frequentie')
plt.xlabel('log(omega)')
plt.ylabel('log(|Am/Av|)')
# Out:
# Text(0, 0.5, 'log(|Am/Av|)')

# %% [markdown]
# ## Conclusie
#
# De massa van de plank is niet 'oneindig' waar deze formules wel van uit gaan. De plank is ook een massa-veer-systeem.
#  Een andere reden is dat de tafel ook trilden door het trillen van de opstelling van onze buren.
# De amplitude is met een factor 10 verlaagt i.p.v. een factor 3. Hierdoor is de verhouding een stuk lager dan uit was gegaan bij de formule.
# Hierdoor is de amplitude een stuk lager dan verwacht met de wiskunde.
# errorbars komen niet perfect over, maar omdat demping meer dan factor 10 is keurt TA het goed

# %% [markdown]
# ## Opdracht 8: Leerdoelen
# Voeg hieronder zelf kopjes toe om aan te geven wat bij welk leerdoel hoort.

# %% [markdown]
# **Leerdoel 1: Inzien dat de parameters in een differentiaalvergelijking ontwerpparameters zijn die een ontwerpruimte opspannen**

# %% [markdown]
# ## Opdracht 2b: Opsplitsen taak 2: afleiding ontwerpeis

# %%
# Bereken hier je benodigde kantelfrequentie
# er moet gedempt worden met een factor 3 bij een f van 5 Hz, A_m/A_v=-1/3 = 1/(1-(2pi*f)^2/(2pi*f_0)^2
#na omschrijven en invullen, blijkt de cutoff frequency f_0= 2.5 Hz precies, dit op papier berekent.

# %%
# Voeg hier je plot in
f_0= 2.5 #hz
g= 9.812 #m/s^2


f= np.linspace(0,15,200)
x= 2*np.pi*f
y0= np.abs(1/(1-((2*np.pi*f)**2)/((2*np.pi*f_0)**2)))
plt.loglog(x,y0)

plt.grid()
plt.title('bodeplot')
plt.xlabel('log(omega)')
plt.ylabel('log(|Am/Av|)')
# Out:
# Text(0, 0.5, 'log(|Am/Av|)')

# %%
# Bereken hier de minimale Delta-x waarbij je aan de eis van de opdracht voldoet.
w_0= 2*np.pi*f_0 #hz
g= 9.812 # m/s^2
delta_x= g/(w_0)**2 #m
print('de waarde van delta x in centimeter is',delta_x*100)
# Out:
# de waarde van delta x in centimeter is 3.9766538155944726

# %% [markdown]
# ## Opdracht 3: Plot de grafiek.

# %%
# Voeg hier je plot in. Lees goed de opdracht wat er in de grafiek moet staan!
# Het is ook handig om je grafiek op te slaan, doe dat door met plt.savefig().

f_0= 2.5 #hz
m= np.linspace(0,3,100)
c_1= (m*g)/delta_x
c_2= (m*g)/(2*delta_x)
c_5= (m*g)/(5*delta_x)


plt.plot(m,c_1, label= 'd')
plt.plot(m,c_2, label= '2d')
plt.plot(m,c_5, label= '5d')
plt.grid()
plt.legend()
plt.title('plot')
plt.xlabel('massa [kg]')
plt.ylabel('veercontstante C [N/m]')
plt.savefig('opdracht5deltaxplot')

# %%
#dit is erbij gekomen na opdracht 6, we hebben gekozen voor een vaste massa van precies 500 g uiteindelijk
#bepalen van veerconstante hierbij

g= 9.812
meind= 0.500 #kg
c_conclusie= (meind*g)/(2*delta_x)

print(c_conclusie)

#dus een veerconstante van ongeveer 61.7 N/m
# Out:
# 61.68502750680849

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# **Gekozen voor 2*$\Delta x$, dus 8 cm**
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# **De gekozen  $\Delta x$ wordt behaald met zowel massa als uitrekking van de veer en onze zelfgemaakte elastieken**
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# **De veer kan maximaal een uitrekking doen van ongeveer $\Delta x$ is 80 cm, en het systeem heeft een limiet qua gewicht erop van ongeveer 5 kg aan massa**
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# **Dit zou genoeg moeten zijn, we verwachtten maximaal 3 kg aan gewicht te gebruiken zoals aangegeven in voorgaande plot, en de uitrekking moet max een 2 keer $\Delta x$ hebben van 8 cm**
#
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# **Voldoen aan de eis zou moeten lukken met gebouwde opstelling en materialen, dus een demping van 5 Hz dempen met een factor 3 met een uitrekking van maximaal 8 cm**
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %% [markdown]
# **Leerdoel 2: Op basis van een differentiaalvergelijking een keuze maken voor parameters en die vervolgens kunnen vertalen in een fysiek ontwerp**

# %% [markdown]
# ## Opdracht 4: Verander $\Delta x$.

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - De massa m te verhogen op de opstelling
# - De veerconstante C verlagen in de opstelling
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
# Als groep gaan we mikken op een $\Delta x$ van 2d is ongeveer 8 cm, dit omdat er altijd extra demping nodig is rekening houdend met bijv wrijving.
# We kiezen om de massa te varieren, omdat dit gemakkelijker is bij iedere stap te wegen t.o.v de veerconstante C

# %% [markdown]
# ## Opdracht 5: Schets.

# %% [markdown]
# ##### schets opstelling:
#
# ![alt text](opdracht5schetsmassaveer.png)

# %%
# Voeg hier je plot in
f_0= 2.5 #hz
g= 9.812 #m/s^2
#bereken nieuwe eigenfrequentie van systeem f_1, 
# uit de differentiaal vergelijking volgt w_1= sqrt(g/delta_x), waarbij onze nieuwe deltax= 2*deltax= 8 cm = 0.08 m

w_1= np.sqrt(g/0.08)
f_1= w_1/(2*np.pi) #eigenfrequentie nieuw syteem in hz
f= np.linspace(0,15,200)
x= 2*np.pi*f
y0= np.abs(1/(1-((2*np.pi*f)**2)/((2*np.pi*f_0)**2)))
y1= np.abs(1/(1-((2*np.pi*f)**2)/((2*np.pi*f_1)**2)))
plt.loglog(x,y0)
plt.loglog(x,y1)
plt.grid()
plt.show
plt.grid()
plt.show
plt.title('amplitudeoverdracht vs frequentie')
plt.xlabel('log(omega)')
plt.ylabel('log(|Am/Av|)')
# Out:
# Text(0, 0.5, 'log(|Am/Av|)')

# %% [markdown]
# ## Opdracht 7: Plotten maar

# %%
# Voeg hier je plot in
f_0= 2.5 #hz
g= 9.812 #m/s^2
#bereken nieuwe eigenfrequentie van systeem f_1, 
# uit de differentiaal vergelijking volgt w_1= sqrt(g/delta_x), waarbij onze nieuwe deltax= 2*deltax= 8 cm = 0.08 m
f_data= np.array([4.9, 5.6, 5.9, 6.2, 6.9, 6.2], dtype=float)
A_v= np.array([3.31, 4.23, 4.47, 5.89, 6.49, 6.77], dtype=float) #in cm
A_m= np.array([0.21, 0.26,0.30, 0.34, 0.48, 0.51], dtype=float) #beide in cm, verhoudingen delen weg

#onzekerheden
u_A_m=1 #cm
u_A_v=1#cm
u_verhouding = np.sqrt((u_A_m/A_m)**2+(u_A_v/A_v)**2)

u_F=0.5

w_1= np.sqrt(g/0.08)
f_1= w_1/(2*np.pi) #eigenfrequentie nieuw syteem in hz
f= np.linspace(0,15,200)
x= 2*np.pi*f
y0= np.abs(1/(1-((2*np.pi*f)**2)/((2*np.pi*f_0)**2)))
y1= np.abs(1/(1-((2*np.pi*f)**2)/((2*np.pi*f_1)**2)))

plt.errorbar(f_data, np.abs(A_m/A_v), xerr=u_F, yerr=u_verhouding, linestyle= 'None')
plt.scatter(f_data, np.abs(A_m/A_v))

plt.plot(x,y0)
plt.plot(x,y1)
plt.xscale('log')
plt.yscale('log')
plt.grid()
plt.show
plt.title('amplitudeoverdracht vs frequentie')
plt.xlabel('log(omega)')
plt.ylabel('log(|Am/Av|)')


# De massa van de plank is niet 'oneindig' waar deze formules wel van uit gaan. De plank is ook een massa-veer-systeem.
# Een andere reden is dat de tafel ook trilden door het trillen van de opstelling van onze buren. 
# De amplitude is met een factor 10 verlaagt i.p.v. een factor 3. Hierdoor is de verhouding een stuk lager dan uit was gegaan bij de formule.
# Hierdoor is de amplitude een stuk lager dan verwacht met de wiskunde. 


#errorbars komen niet perfect over, maar omdat demping meer dan factor 10 is keurt TA het goed
# Out:
# Text(0, 0.5, 'log(|Am/Av|)')

# %%
# Als je met Python je resultaten wil laten zien: voeg hier je code in.

# %% [markdown]
# #### Als je je figuren onderweg opgeslagen hebt, kan je ze hier invoegen:
# <img src="sinusmooi.png" width="400">
